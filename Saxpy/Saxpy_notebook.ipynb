# %% [markdown]
# # Notebook for Saxpy Benchmarks Visualization

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
np.set_printoptions(suppress = True) # deactivates scientific number format
# %load_ext autoreload
# %autoreload 2
# %load_ext Cython

# %%
#Plotting Function
def Benchmark (Results):
    # Plotting
    elements = Results.shape[0]
    plt.figure(figsize=(15,9))
    plt.plot(np.log2(N[:elements]),Results[:], linestyle='--', marker='o', color='b')
    plt.yscale("log")
    plt.title("Results [cpu]")
    plt.xlabel("Array Size")
    plt.ylabel("Runtime (ms)")
    x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
    plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
    plt.grid()
    plt.show()

# %%
# Plot Template
'''
elements = Saxpy_Python_For_Loop_CPU.shape[0]
# Plotting
plt.figure(figsize=(15,9))
plt.plot(np.log2(N[:elements]),Saxpy_Python_For_Loop_CPU[:], linestyle='--', marker='o', color='b')
plt.yscale("log")
plt.title("SAXPY Python For Loop [cpu]")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()
'''
# Out:
# '\nelements = Saxpy_Python_For_Loop_CPU.shape[0]\n# Plotting\nplt.figure(figsize=(15,9))\nplt.plot(np.log2(N[:elements]),Saxpy_Python_For_Loop_CPU[:], linestyle=\'--\', marker=\'o\', color=\'b\')\nplt.yscale("log")\nplt.title("SAXPY Python For Loop [cpu]")\nplt.xlabel("Array Size")\nplt.ylabel("Runtime (ms)")\nx_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]\nplt.xticks(np.arange(1, elements + 1,1), x_tick_labels)\nplt.grid()\nplt.show()\n'

# %%
N = [2,4,8,16,32,64,128,256,512,1024,2048,4096,8192,16384,32768,65536,131072,262144,524288,1048576,2097152,4194304,8388608,16777216,33554432,67108864,134217728,268435456,536870912,1073741824]

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # Single Core CPU

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 1. Saxpy Python For Loop CPU

# %%
# Reading the csv into an array
Saxpy_Python_For_Loop_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_For_Loop_CPU.csv", delimiter=",")

# %%
# Runtime in Seconds
print(Saxpy_Python_For_Loop_CPU/1000)
# Out:
# [  0.00000798   0.00000136   0.00000215   0.0000037    0.00000694
#    0.00001348   0.00002637   0.00005217   0.00010655   0.00021747
#    0.00043006   0.00086422   0.00170798   0.00351955   0.00719467
#    0.0142257    0.02835696   0.0564126    0.11280545   0.22568724
#    0.4489406    0.90058941   1.79491854   3.59327415   7.19847974
#   14.3887894   28.79499091  57.49219741 114.94528015 229.65843071]

# %%
Benchmark (Saxpy_Python_For_Loop_CPU)

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 2. Saxpy Python Numpy CPU

# %%
# Reading the csv into an array
Saxpy_Python_Numpy_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numpy_CPU.csv", delimiter=",")

# %%
# Runtime in Seconds
print(Saxpy_Python_Numpy_CPU/1000)
# Out:
# [0.00001004 0.00000165 0.00000119 0.00000119 0.00000108 0.00000124
#  0.00000114 0.00000138 0.00000139 0.00000154 0.00000161 0.00000197
#  0.00000316 0.00000392 0.00000712 0.00002363 0.000045   0.00008721
#  0.00026003 0.00056307 0.00117359 0.00299133 0.00760692 0.01587901
#  0.03240085 0.06569692 0.13030958 0.26386144 0.52162446 1.05515195]

# %%
Benchmark (Saxpy_Python_Numpy_CPU)

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 3. Saxpy Python Numba CPU

# %%
# check system information
#import numba
#!numba -s

# %%
# Reading the csv into an array
Saxpy_Python_Numba_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_CPU.csv", delimiter=",")

# %%
print(Saxpy_Python_Numba_CPU/1000)
# Out:
# [0.00633106 0.00000123 0.00000075 0.00000075 0.00000085 0.00000069
#  0.00000085 0.00000077 0.00000076 0.00000077 0.00000087 0.00000101
#  0.00000151 0.00000197 0.00000361 0.00000818 0.00001783 0.00004257
#  0.00008565 0.0002203  0.00054531 0.0012621  0.00299318 0.00550141
#  0.01145999 0.02343972 0.04750594 0.09604659 0.1932264  0.38773955]

# %%
Benchmark (Saxpy_Python_Numba_CPU)

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 4. Saxpy Python Cython CPU

# %%
# run this in src/Saxpy_Cython to build: pyhon setup.py build_ext --inplace

# %%
# Reading the csv into an array
Saxpy_Python_Cython_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_CPU.csv", delimiter=",")

# %%
print(Saxpy_Python_Cython_CPU/1000)
# Out:
# [0.00000889 0.00000089 0.00000066 0.00000056 0.00000075 0.00000079
#  0.0000008  0.00000063 0.00000076 0.00000074 0.00000086 0.00000111
#  0.00000173 0.00000285 0.00000508 0.00000921 0.00002092 0.00004494
#  0.0000879  0.0002555  0.00058986 0.00128185 0.0029515  0.00544772
#  0.0110849  0.02274619 0.04575344 0.09263424 0.1859901  0.37388005]

# %%
Benchmark (Saxpy_Python_Cython_CPU)

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 5. Saxpy C For Loop CPU

# %%
Saxpy_C_For_Loop_CPU = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_CPU.csv", delimiter=" ")*1000

# %%
print(Saxpy_C_For_Loop_CPU)
# Out:
# [  0.000024     0.0000163    0.00001735   0.00001615   0.00001635
#    0.00001685   0.00002035   0.00002815   0.00003725   0.00005845
#    0.00009895   0.0003402    0.0009595    0.001272     0.0031358
#    0.00656395   0.01598695   0.04116745   0.0871477    0.22760485
#    0.66254215   1.5462163    3.11000945   6.4507517   13.017337
#   24.88454585  48.90475125  98.18399475 195.30669445 396.0851275 ]

# %%
elements = Saxpy_C_For_Loop_CPU .shape[0]
plt.figure(figsize=(15,9))
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_CPU [:], linestyle='--', marker='o')
plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 6. Saxpy SWIG CPU

# %%
# Reading the csv into an array
Saxpy_C_For_Loop_SWIG_CPU = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_SWIG_CPU.csv", delimiter=",")

# %%
print(Saxpy_C_For_Loop_SWIG_CPU/1000)
# Out:
# [0.00000641 0.00000042 0.00000029 0.0000003  0.00000029 0.00000033
#  0.00000026 0.00000027 0.00000029 0.00000038 0.00000037 0.0000006
#  0.00000099 0.00000176 0.00000304 0.00000699 0.00001637 0.0000392
#  0.00008533 0.00020591 0.00056133 0.00138029 0.00343279 0.00572219
#  0.01191421 0.02440535 0.0496313  0.10026362 0.20207932 0.40611453]

# %%
elements = Saxpy_C_For_Loop_SWIG_CPU .shape[0]
plt.figure(figsize=(15,9))
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_SWIG_CPU [:], linestyle='--', marker='o')
plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 7. Saxpy Julia CPU

# %%
# Reading the csv into an array
Saxpy_Julia_For_Loop_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Julia_For_Loop_CPU.csv", delimiter=",")/1_000_000

# %%
print(Saxpy_Julia_For_Loop_CPU)
# Out:
# [  0.00001194   0.00001253   0.00001401   0.00001794   0.0000122
#    0.00001467   0.00001591   0.00002046   0.00003018   0.00005464
#    0.00009054   0.00016429   0.00054071   0.00105433   0.00205717
#    0.00519963   0.00976612   0.03632656   0.07712574   0.15427057
#    0.32292311   1.0389489    2.64918099   5.71347826  11.92060853
#   24.04465954  48.74020326  98.17121753 197.68566354 398.22934754]

# %% [markdown]
# ___

# %%
# Reading the csv into an array
Saxpy_Julia_Vectorized_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Vectorized_CPU.csv", delimiter=",")/1_000_000

# %%
print(Saxpy_Julia_Vectorized_CPU)
# Out:
# [  0.00001275   0.00001323   0.0000151    0.00001874   0.00001362
#    0.00001614   0.0000167    0.00002117   0.00003063   0.00005954
#    0.00009244   0.00016575   0.00054657   0.00106777   0.00205765
#    0.00519938   0.01088676   0.03786817   0.07746516   0.15489028
#    0.33193302   1.09358595   2.64013194   5.82856975  12.0888744
#   24.28815151  48.56254053  98.21506637 195.61122369 391.28088954]

# %% [markdown]
# ___

# %%
elements = Saxpy_Julia_For_Loop_CPU .shape[0]
plt.figure(figsize=(15,9))
plt.plot(np.log2(N[:elements]),Saxpy_Julia_For_Loop_CPU [:], linestyle='--', marker='o', color='r')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Vectorized_CPU [:], linestyle='--', marker='o', color='b')
plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # Multiple Core CPU

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 8. Saxpy Python Numba Multithread CPU

# %%
# Reading the csv into an array
Saxpy_Python_Numba_Multithread_CPU1 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU1.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU2 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU2.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU3 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU3.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU4 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU4.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU5 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU5.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU6 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU6.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU7 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU7.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU8 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU8.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU9 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU9.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU10 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU10.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU11 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU11.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU12 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU12.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU13 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU13.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU14 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU14.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU15 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU15.csv", delimiter=",")
Saxpy_Python_Numba_Multithread_CPU16 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU16.csv", delimiter=",")

# %%
print(Saxpy_Python_Numba_Multithread_CPU1[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU2[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU3[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU4[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU5[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU6[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU7[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU8[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU9[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU10[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU11[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU12[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU13[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU14[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU15[-1]/1000)
print(Saxpy_Python_Numba_Multithread_CPU16[-1]/1000)
# Out:
# 0.4037321090698242
# 0.3375364661216736
# 0.336749267578125
# 0.3411406397819519
# 0.3440029978752136
# 0.3405638575553894
# 0.3369310021400452
# 0.33027431964874265
# 0.34374399185180665
# 0.3432336330413818
# 0.3451227068901062
# 0.34732120037078856
# 0.34870731830596924
# 0.3513351798057556
# 0.3538761854171753
# 0.3565509796142578

# %%
elements = Saxpy_Python_Numba_Multithread_CPU16.shape[0]
plt.figure(figsize=(15,9))

plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU1[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU2[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU3[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU4[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU5[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU6[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU7[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU8[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU9[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU10[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU11[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU12[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU13[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU14[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU15[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU16[:], linestyle='--', marker='o')

plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 9. Saxpy Python Cython Multithread CPU

# %%
# Reading the csv into an array
Saxpy_Python_Cython_Multithread_CPU1 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU1.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU2 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU2.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU3 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU3.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU4 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU4.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU5 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU5.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU6 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU6.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU7 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU7.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU8 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU8.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU9 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU9.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU10 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU10.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU11 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU11.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU12 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU12.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU13 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU13.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU14 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU14.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU15 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU15.csv", delimiter=",")
Saxpy_Python_Cython_Multithread_CPU16 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU16.csv", delimiter=",")

# %%
print(Saxpy_Python_Cython_Multithread_CPU1[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU2[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU3[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU4[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU5[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU6[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU7[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU8[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU9[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU10[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU11[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU12[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU13[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU14[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU15[-1]/1000)
print(Saxpy_Python_Cython_Multithread_CPU16[-1]/1000)
# Out:
# 0.4417039752006531
# 0.34432072639465333
# 0.3247481107711792
# 0.3256051063537598
# 0.3226226806640625
# 0.3282832741737366
# 0.3248654127120972
# 0.34698617458343506
# 0.34357370138168336
# 0.33750358819961546
# 0.3315823435783386
# 0.33662216663360595
# 0.33984702825546265
# 0.3392550706863403
# 0.3386955499649048
# 0.3587206482887268

# %%
elements = Saxpy_Python_Numba_Multithread_CPU16.shape[0]
plt.figure(figsize=(15,9))

plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU1[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU2[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU3[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU4[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU5[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU6[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU7[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU8[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU9[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU10[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU11[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU12[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU13[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU14[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU15[:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU16[:], linestyle='--', marker='o')

plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 10. Saxpy C Multithread CPU

# %%
Saxpy_C_For_Loop_Multithread_CPU1 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU1.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU2 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU2.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU3 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU3.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU4 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU4.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU5 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU5.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU6 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU6.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU7 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU7.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU8 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU8.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU9 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU9.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU10 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU10.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU11 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU11.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU12 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU12.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU13 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU13.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU14 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU14.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU15 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU15.csv", delimiter=" ")*1000
Saxpy_C_For_Loop_Multithread_CPU16 = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU16.csv", delimiter=" ")*1000

# %%
print(Saxpy_C_For_Loop_Multithread_CPU1[-1])
print(Saxpy_C_For_Loop_Multithread_CPU2[-1])
print(Saxpy_C_For_Loop_Multithread_CPU3[-1])
print(Saxpy_C_For_Loop_Multithread_CPU4[-1])
print(Saxpy_C_For_Loop_Multithread_CPU5[-1])
print(Saxpy_C_For_Loop_Multithread_CPU6[-1])
print(Saxpy_C_For_Loop_Multithread_CPU7[-1])
print(Saxpy_C_For_Loop_Multithread_CPU8[-1])
print(Saxpy_C_For_Loop_Multithread_CPU9[-1])
print(Saxpy_C_For_Loop_Multithread_CPU10[-1])
print(Saxpy_C_For_Loop_Multithread_CPU11[-1])
print(Saxpy_C_For_Loop_Multithread_CPU12[-1])
print(Saxpy_C_For_Loop_Multithread_CPU13[-1])
print(Saxpy_C_For_Loop_Multithread_CPU14[-1])
print(Saxpy_C_For_Loop_Multithread_CPU15[-1])
print(Saxpy_C_For_Loop_Multithread_CPU16[-1])
# Out:
# 418.05072533316
# 353.467642999021
# 343.185721332702
# 336.58402566895
# 329.27880333590997
# 327.19762333484397
# 340.651572667412
# 350.576361003429
# 346.59167633556797
# 350.212298663488
# 343.512902332198
# 341.444313666822
# 344.60561866581
# 344.097876998906
# 343.339229334864
# 349.920200666626

# %%
elements = Saxpy_C_For_Loop_CPU .shape[0]
plt.figure(figsize=(15,9))

plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_CPU [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU1 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU2 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU3 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU4 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU5 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU6 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU7 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU8 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU9 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU10 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU11 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU12 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU13 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU14 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU15 [:], linestyle='--', marker='o')
plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU16 [:], linestyle='--', marker='o')


plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 11. Saxpy Julia Multithread CPU

# %%
# Reading the csv into an array
Saxpy_Julia_Multithread_CPU1 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU1.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU2 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU2.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU3 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU3.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU4 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU4.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU5 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU5.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU6 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU6.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU7 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU7.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU8 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU8.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU9 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU9.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU10 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU10.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU11 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU11.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU12 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU12.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU13 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU13.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU14 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU14.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU15 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU15.csv", delimiter=",")/1_000_000
Saxpy_Julia_Multithread_CPU16 = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU16.csv", delimiter=",")/1_000_000

# %%
print(Saxpy_Julia_Multithread_CPU1[-1])
print(Saxpy_Julia_Multithread_CPU2[-1])
print(Saxpy_Julia_Multithread_CPU3[-1])
print(Saxpy_Julia_Multithread_CPU4[-1])
print(Saxpy_Julia_Multithread_CPU5[-1])
print(Saxpy_Julia_Multithread_CPU6[-1])
print(Saxpy_Julia_Multithread_CPU7[-1])
print(Saxpy_Julia_Multithread_CPU8[-1])
print(Saxpy_Julia_Multithread_CPU9[-1])
print(Saxpy_Julia_Multithread_CPU10[-1])
print(Saxpy_Julia_Multithread_CPU11[-1])
print(Saxpy_Julia_Multithread_CPU12[-1])
print(Saxpy_Julia_Multithread_CPU13[-1])
print(Saxpy_Julia_Multithread_CPU14[-1])
print(Saxpy_Julia_Multithread_CPU15[-1])
print(Saxpy_Julia_Multithread_CPU16[-1])
# Out:
# 430.49327475
# 338.13600180000003
# 324.7549911875
# 314.1928934375
# 327.9519764375
# 331.0554535
# 336.2915453333333
# 340.2704030666667
# 339.0456088
# 336.53754373333334
# 327.4562263125
# 336.45211266666666
# 336.62228073333335
# 338.2493743333333
# 344.49694439999996
# 344.7827451333333

# %%
print(Saxpy_Julia_Multithread_CPU4[-3])
# Out:
# 78.3062263125

# %%
elements = Saxpy_Julia_Multithread_CPU1.shape[0]
plt.figure(figsize=(15,9))

plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU1 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU2 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU3 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU4 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU5 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU6 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU7 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU8 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU9 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU10 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU11 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU12 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU13 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU14 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU15 [:], linestyle='--', marker='o', color='black')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU16 [:], linestyle='--', marker='o', color='black')

plt.yscale("log")

plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
#plt.xlim(28,31)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # GPU

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 12. Saxpy Python CuPy Numba GPU

# %%
# Reading the csv into an array
Saxpy_Python_Numba_Cupy_GPU= np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Cupy_GPU.csv", delimiter=",")

# %%
print(Saxpy_Python_Numba_Cupy_GPU)
# Out:
# [ 3.8921922   0.25873743  0.24977817  0.2285092   0.2511141   0.2457991
#   0.22568073  0.23862357  0.23534683  0.2841906   0.3087524   0.34644337
#   0.388255    0.39237043  0.3466657   0.3314434   0.25528527  0.24341723
#   0.26963143  0.36848867  0.7234293   1.3778177   2.8182447   5.66059697
#  11.88983533 22.882686   41.95400943 81.07305007]

# %%
elements = Saxpy_Python_Numba_Cupy_GPU.shape[0]
plt.figure(figsize=(15,9))

plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Cupy_GPU [:], linestyle='--', marker='o', color='black')

plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 13. Saxpy C CUDA GPU

# %%
Saxpy_C_CUDA_GPU = np.genfromtxt("Benchmark_Results/Saxpy_C_CUDA_GPU.csv", delimiter=" ")*1000

# %%
print(Saxpy_C_CUDA_GPU)
# Out:
# [ 0.00634475  0.00606975  0.00584985  0.02798675  0.0058988   0.00546875
#   0.016426    0.00559515  0.00570365  0.02306965  0.0060441   0.00717655
#   0.00781     0.03066785  0.03314325  0.05500185  0.0849285   0.10827885
#   0.1615467   0.16281615  0.20655395  0.2597748   0.41566755  0.72755465
#   1.3457006   2.6990558   5.35821805 11.06297965 21.6496493 ]

# %%
elements = Saxpy_C_CUDA_GPU.shape[0]
plt.figure(figsize=(15,9))

plt.plot(np.log2(N[:elements]),Saxpy_C_CUDA_GPU [:], linestyle='--', marker='o', color='black')

plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 14. Saxpy Julia GPU

# %% [markdown]
# ___

# %%
# Reading the csv into an array
Saxpy_Julia_GPU= np.genfromtxt("Benchmark_Results/Saxpy_Julia_GPU.csv", delimiter=",")/1_000_000

# %%
print(Saxpy_Julia_GPU)
# Out:
# [ 0.00925187  0.00909796  0.00933339  0.00955027  0.00901439  0.00901411
#   0.00892298  0.00906036  0.00929817  0.00939355  0.00929909  0.00945313
#   0.00942859  0.00930809  0.00956838  0.00980234  0.01073617  0.01178011
#   0.01460385  0.05216305  0.09385088  0.21013358  0.40321429  0.78171441
#   1.52565819  3.31807272  6.05935674 11.46957329 22.23040443]

# %% [markdown]
# ___

# %%
# Reading the csv into an array
Saxpy_Julia_Kernel_GPU= np.genfromtxt("Benchmark_Results/Saxpy_Julia_Kernel_GPU.csv", delimiter=",")/1_000_000

# %%
print(Saxpy_Julia_Kernel_GPU)
# Out:
# [ 0.00755793  0.0075919   0.00761384  0.00774774  0.00765707  0.00765611
#   0.00749956  0.00755927  0.0078028   0.00786028  0.00804177  0.00790682
#   0.00790857  0.00773869  0.00805794  0.0083791   0.00977738  0.01163431
#   0.01653964  0.04919148  0.08956676  0.2059177   0.38210615  0.7380445
#   1.43933763  3.13023487  5.84610807 10.97349516 21.14943657]

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
elements = Saxpy_Julia_GPU.shape[0]
plt.figure(figsize=(15,9))

plt.plot(np.log2(N[:elements]),Saxpy_Julia_GPU [:], linestyle='--', marker='o', color='orange')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Kernel_GPU [:], linestyle='--', marker='o', color='purple')

plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # 15. Saxpy Julia GPU M1

# %% [markdown]
# ___

# %%
# Reading the csv into an array
Saxpy_Julia_GPU_M1= np.genfromtxt("Benchmark_Results/Saxpy_Julia_GPU_M1_Vectorized.csv", delimiter=",")/1_000_000

# %%
print(Saxpy_Julia_GPU_M1)
# Out:
# [  0.15949011   0.15970235   0.15977311   0.15896441   0.15962798
#    0.15928011   0.15869323   0.15935375   0.15941932   0.15351391
#    0.15956      0.15937562   0.15907041   0.1561017    0.15945465
#    0.15893129   0.15699394   0.15790516   0.15747219   0.18471293
#    0.46864333   0.8740039    1.68010057   3.24835278   6.24636708
#   12.4862252   24.87704169  49.93502028 101.24539582]

# %% [markdown]
# ___

# %%
# Reading the csv into an array
Saxpy_Julia_Kernel_GPU_M1= np.genfromtxt("Benchmark_Results/Saxpy_Julia_GPU_M1_Kernel.csv", delimiter=",")/1_000_000

# %%
print(Saxpy_Julia_Kernel_GPU_M1)
# Out:
# [  0.14549541   0.1443691    0.14579299   0.14531187   0.14402601
#    0.14699849   0.14702459   0.14705863   0.14675359   0.1405367
#    0.14706338   0.14397588   0.14664272   0.14710047   0.14587321
#    0.14560953   0.14610353   0.1453041    0.14413511   0.20097682
#    0.46725449   0.87337088   1.6747777    3.2439691    6.31957992
#   12.5469753   25.05080792  50.23681913 100.97210674]

# %% [markdown]
# ___

# %% [markdown]
# ___

# %%
elements = Saxpy_Julia_GPU_M1.shape[0]
plt.figure(figsize=(15,9))

plt.plot(np.log2(N[:elements]),Saxpy_Julia_GPU_M1 [:], linestyle='--', marker='o', color='orange')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Kernel_GPU_M1 [:], linestyle='--', marker='o', color='purple')

plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# # All Benchmarks

# %%
# Load all the data

# Single Core CPU
#Saxpy_Python_For_Loop_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_For_Loop_CPU.csv", delimiter=",")
#Saxpy_Python_Numpy_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numpy_CPU.csv", delimiter=",")
#Saxpy_Python_Numba_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_CPU.csv", delimiter=",")
#Saxpy_Python_Cython_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_CPU.csv", delimiter=",")
#Saxpy_C_For_Loop_CPU = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_CPU.csv", delimiter=" ")*1000
#Saxpy_C_For_Loop_SWIG_CPU = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_SWIG_CPU.csv", delimiter=",")
#Saxpy_Julia_For_Loop_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Julia_For_Loop_CPU.csv", delimiter=",")/1_000_000
#Saxpy_Julia_Vectorized_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Vectorized_CPU.csv", delimiter=",")/1_000_000

# Multiple Core CPU
#Saxpy_Python_Numba_Multithread_CPU1 = np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Multithreading_CPU1.csv", delimiter=",")
#Saxpy_Python_Cython_Multithread_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Python_Cython_Multithread_CPU.csv", delimiter=",")
#Saxpy_C_For_Loop_Multithread_CPU = np.genfromtxt("Benchmark_Results/Saxpy_C_For_Loop_Multithread_CPU.csv", delimiter=" ")*1000
#Saxpy_Julia_Multithread_CPU = np.genfromtxt("Benchmark_Results/Saxpy_Julia_Multithread_CPU.csv", delimiter=",")/1_000_000

# GPU
#Saxpy_Python_Numba_Cupy_GPU= np.genfromtxt("Benchmark_Results/Saxpy_Python_Numba_Cupy_GPU.csv", delimiter=",")
#Saxpy_C_CUDA_GPU = np.genfromtxt("Benchmark_Results/Saxpy_C_CUDA_GPU.csv", delimiter=" ")*1000
#Saxpy_Julia_GPU= np.genfromtxt("Benchmark_Results/Saxpy_Julia_GPU.csv", delimiter=",")/1_000_000
#Saxpy_Julia_Kernel_GPU= np.genfromtxt("Benchmark_Results/Saxpy_Julia_Kernel_GPU.csv", delimiter=",")/1_000_000
#Saxpy_Julia_GPU_M1= np.genfromtxt("Benchmark_Results/Saxpy_Julia_GPU_M1_Vectorized.csv", delimiter=",")/1_000_000
#Saxpy_Julia_Kernel_GPU_M1= np.genfromtxt("Benchmark_Results/Saxpy_Julia_GPU_M1_Kernel.csv", delimiter=",")/1_000_000

# %%
# Plotting
elements = Saxpy_Julia_Vectorized_CPU.shape[0]-1
plt.figure(figsize=(15,9))

# Single Core CPU
#plt.plot(np.log2(N[:elements]),Saxpy_Python_For_Loop_CPU[:-2], linestyle='--', marker='o', color='r', label='Python_For_Loop_CPU')
#plt.plot(np.log2(N[:elements]),Saxpy_Python_Numpy_CPU[:-2], linestyle='--', marker='o', color='k', label='Python_Numpy_CPU')
#plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_CPU[:-2], linestyle='--', marker='o', color='g', label='Python_Numba_CPU')
#plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_CPU[:-2], linestyle='--', marker='x', color='r', label='Python_Cython_CPU')
#plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_CPU[:-2], linestyle='--', marker='x', color='b', label='C_CPU')
#plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_SWIG_CPU[:-2], linestyle='--', marker='x', color='c', label='SWIG_CPU')
#plt.plot(np.log2(N[:elements]),Saxpy_Julia_For_Loop_CPU [:-2], linestyle='--', marker='o', color='m', label='Julia_For_Loop_CPU')
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Vectorized_CPU [:-1], linestyle='--', marker='o', color='y', label='Julia_Vectorized_CPU')

# Multiple Core CPU
#plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Multithread_CPU16[:-2], linestyle='--', marker='o')
#plt.plot(np.log2(N[:elements]),Saxpy_Python_Cython_Multithread_CPU16[:-2], linestyle='--', marker='x', color='b')
#plt.plot(np.log2(N[:elements]),Saxpy_C_For_Loop_Multithread_CPU16[:-2], linestyle='--', marker='o', color='r')    
plt.plot(np.log2(N[:elements]),Saxpy_Julia_Multithread_CPU16 [:-1], linestyle='--', marker='o', color='black')

# GPU
#plt.plot(np.log2(N[:elements]),Saxpy_Python_Numba_Cupy_GPU[:], linestyle='--', marker='o', color='b')
#plt.plot(np.log2(N[:elements]),Saxpy_C_CUDA_GPU[:-2], linestyle='--', marker='o', color='g')  
#plt.plot(np.log2(N[:elements-1]),Saxpy_Julia_GPU [:], linestyle='--', marker='o', color='orange')
plt.plot(np.log2(N[:elements-1]),Saxpy_Julia_Kernel_GPU [:-1], linestyle='--', marker='o', color= 'red')
#plt.plot(np.log2(N[:elements]),Saxpy_Julia_GPU_M1 [:], linestyle='--', marker='o', color='orange')
#plt.plot(np.log2(N[:elements]),Saxpy_Julia_Kernel_GPU_M1 [:], linestyle='--', marker='o', color='purple')


plt.yscale("log")
plt.title("Saxpy Benchmark")
plt.xlabel("Array Size")
plt.ylabel("Runtime (ms)")
plt.yscale("log")
x_tick_labels = ["$2^{" + str(i) + "}$" for i in range(1, elements + 1,1)]
plt.xticks(np.arange(1, elements + 1,1), x_tick_labels)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# ___
